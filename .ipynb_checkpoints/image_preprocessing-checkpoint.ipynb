# %%
from skimage import io as skio
url = '2.png'
img = skio.imread(url)

# %%
from skimage import filters
sobel = filters.sobel(img)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['figure.dpi'] = 200

# %%
plt.imshow(sobel)

# %%
blurred = filters.gaussian(sobel, sigma=2.0)
plt.imshow(blurred)
# Out:
# C:\Users\pc\anaconda3\envs\ocr\lib\site-packages\skimage\_shared\utils.py:348: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.
#   return func(*args, **kwargs)

# %%
import numpy as np
light_spots = np.array((img > 150).nonzero()).T
print(light_spots)
# Out:
# [[  0   0   0]
#  [  0   0   1]
#  [  0   0   2]
#  ...
#  [ 29 149   0]
#  [ 29 149   1]
#  [ 29 149   2]]

# %%
light_spots.shape
# Out:
# (12303, 3)

# %%
img.shape
# Out:
# (30, 150, 3)

# %%
plt.plot(light_spots[:, 1], light_spots[:, 0], 'o')
plt.imshow(img)
plt.title('light spots in image')
# Out:
# Text(0.5, 1.0, 'light spots in image')

# %%
dark_spots = np.array((img < 3).nonzero()).T

# %%
plt.plot(dark_spots[:, 1], dark_spots[:, 0], 'o')
plt.imshow(img)
plt.title('dark spots in image')
# Out:
# Text(0.5, 1.0, 'dark spots in image')

# %%
from scipy import ndimage as ndi
bool_mask = np.zeros(img.shape, dtype=np.bool)
bool_mask[tuple(light_spots.T)] = True
bool_mask[tuple(dark_spots.T)] = True
seed_mask, num_seeds = ndi.label(bool_mask)
num_seeds
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_26020\275166160.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   bool_mask = np.zeros(img.shape, dtype=np.bool)
# 9

# %%
from skimage.segmentation  import morphology
ws = morphology.watershed(blurred, seed_mask)
plt.imshow(ws)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 from skimage.segmentation  import morphology
#       2 ws = morphology.watershed(blurred, seed_mask)
#       3 plt.imshow(ws)
#
# ImportError: cannot import name 'morphology' from 'skimage.segmentation' (C:\Users\pc\anaconda3\envs\ocr\lib\site-packages\skimage\segmentation\__init__.py)

# %%
morphology.
